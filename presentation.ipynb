# %% [raw]
# ---
# title: The Power of Bayes in Industry
# subtitle: Your Business Model is Your Data Generating Process
# author: Dante Gates, PyMCon Web Series 2023
# format:
#   revealjs:
#     self-contained: true
#     echo: true
#     code-fold: false
#     theme: dark
#     slide-number: true
# highlight-style: github-light
# jupyter: python3
# ---

# %% [markdown]
# # About [Me](https://dantegates.github.io/) {auto-animate=true}
#
#
# <table>
#     <tr>
#         <td wdith=60%>
#             <img src="assets/dante.jpg">
#         </td>
#         <td style="text-align left; vertical-align: middle">
#             <blockquote style="font-size: .9em">
#                 Husband and father
#
#                 Philly data scientist
#
#                 Wrote a haiku once
#             </blockquote>
#         </td>
#     </tr>
#     <tr>
#         <td colspan=2 style="text-align: center">
#             [dantegates.github.io](https://dantegates.github.io)
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Outline
#
# ![](assets/outline.png){fig-align=center}

# %% [markdown]
# # Getting Started

# %% [markdown]
# ## What is a DGP? {auto-animate=true}
#
# <br>
#
# Disambiguating an overloaded term:
#
# ::: {data-id="true dgp"}
# - The *True* Data Generating Process
# :::
# ::: {data-id="modeled dgp"}
# - The True DGP *as modeled*
# :::

# %% [markdown]
# ## Modeling from _first principles_ {auto-animate=true visibility="uncounted"}
#
# <br>
# <br>
#
# :::: {.columns}
#
# ::: {.column}
#
# - The *True* Data Generating Process
# - The True DGP *as modeled*
#
# :::
#
# ::: {.column}
# <table>
# <tr>
#     <td style="vertical-align: middle">
#         <p style="font-size: 3.5em">}</p>
#     </td>
#     <td style="vertical-align: middle">
#         **Goal**: Align these
#     </td>
# </tr>
# </table>
# :::
#
# ::::

# %% [markdown]
# # Motivating Example
#
# Stan Case Study: [Golf putting](https://mc-stan.org/users/documentation/case-studies/golf.html)

# %% [markdown]
# ## Golf puts, a first principles model
#
# <br>

# %%
#| echo: false

import io

import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv(
    io.StringIO('x n y\n2 1443 1346\n3 694 577\n4 455 337\n5 353 208\n6 272 149\n7 256 136\n8 240 111\n9 217 69\n10 200 67\n11 237 75\n12 202 52\n13 192 46\n14 174 54\n15 167 28\n16 201 27\n17 195 31\n18 191 33\n19 147 20\n20 152 24'),
    sep=' ')

display(df.head())
# Out:
#    x     n     y
# 0  2  1443  1346
# 1  3   694   577
# 2  4   455   337
# 3  5   353   208
# 4  6   272   149

# %% [markdown]
# ## The true DGP
#
#
# <table>
#     <tr>
#         <td width=85% style="text-align: center; vertical-align: middle">
#             <br>
#             <img width=70% src="assets/putting-true-dgp-photo.jpeg">
#         </td>
#     </tr>
#     <tr>
#         <td style="font-size: .5em; text-align: center">
#             Photo Credit: <a src="https://www.insidescience.org/news/should-golfers-keep-flagstick-cup-when-they-putt">insidescience.org</a>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## The DGP as Modeled {auto-animate=true}
#
# <br>
#
# <table>
#     <tr>
#         <td style="width: 55%; vertical-align: middle; text-align: center">
#             <img src="assets/putting-first-principles.png">
#         </td>
#     </tr>
#     <tr>
#         <td colspan="2" style="text-align: center; font-size: .5em">
#             <p>
#                   Image Source: <a href="https://mc-stan.org/users/documentation/case-studies/golf.html">Stan Development Team</a>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## First principles fit {auto-animate=true}
#
# <table>
#     <tr>
#         <td style="width: 75%; vertical-align: middle; text-align: center">
#             <img width=65% src="assets/putting-fit.png">
#         </td>
#     </tr>
#     <tr>
#         <td colspan="2" style="text-align: center; font-size: .5em">
#             <p>
#                   Image Source: <a href="https://mc-stan.org/users/documentation/case-studies/golf.html">Stan Development Team</a>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## First principles fit {auto-animate=true visibility=uncounted}
#
# <table>
#     <tr>
#         <td style="width: 65%; vertical-align: middle; text-align: center">
#             <img width=85% src="assets/putting-fit.png">
#         </td>
#         <td>
#             **Summary**
#             <ul style="font-size: .9em; margin: 0">
#                 <li>Began with basic assumptions</li>
#                 <li>Sketched mental model</li>
#                 <li>Let the math play out</li>
#                 <li>Fit the model</li>
#
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td colspan="2" style="text-align: center; font-size: .5em">
#             <p>
#                   Image Source: <a href="https://mc-stan.org/users/documentation/case-studies/golf.html">Stan Development Team</a>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## First principles fit {auto-animate=true visibility=uncounted}
#
# <table>
#     <tr>
#         <td style="width: 65%; vertical-align: middle; text-align: center; margin: 0">
#             <img width=85% src="assets/putting-fit.png">
#         </td>
#         <td style="margin: 0">
#             **Modeled outcome**
#             <br>
#             <br>
#             <p style="font-size: .8em; text-align: center; margin: 0 0 .5em 0">**Will the ball go in the hole?**</p>
#             <p style="font-size: .8em; text-align: center; margin: 0 0 .5em 0">_-not-_</p>
#             <p style="font-size: .8em; text-align: center; margin: 0 0 .5em 0">**y=0/1?**</p>
#         </td>
#     </tr>
#     <tr>
#         <td colspan="2" style="text-align: center; font-size: .5em">
#             <p>
#                   Image Source: <a href="https://mc-stan.org/users/documentation/case-studies/golf.html">Stan Development Team</a>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## First principles fit {auto-animate=true visibility=uncounted}
#
# <table>
#     <tr>
#         <td style="width: 65%; vertical-align: middle; text-align: center; margin: 0">
#             <img width=85% src="assets/putting-fit.png">
#         </td>
#         <td style="margin: 0">
#             **Black Box Model?**
#             <br>
#             <br>
#             <img style="vertical-align: middle;" src="assets/black-box-model.png">
#         </td>
#     </tr>
#     <tr>
#         <td colspan="2" style="text-align: center; font-size: .5em">
#             <p>
#                   Image Source: <a href="https://mc-stan.org/users/documentation/case-studies/golf.html">Stan Development Team</a>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Useful, or cute party trick?
#
# <br>
# <br>
# <div style="font-size: 8em; text-align: center">
# 👶
# </div>

# %% [markdown]
# # {background-image=assets/perpay.png}

# %% [markdown]
# ## Credit building through E-Commerce

# %% [markdown]
# <div align=center style="text-align: center">
# <img width=80% src="assets/perpay-shopping.png">
# </div>

# %% [markdown]
# # Sketching

# %% [markdown]
# ## Modeling loan maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column width=50%}
# ```{.python code-line-numbers="4"}
# with pm.Model():
#     ...
#
#     D = ...
#
#     ...
# ```
# :::
#
# ::: {.column width=25% style="font-size: .7em;"}
# **First Principles TODO**
#
# - [ ] $P(L) = 1 - P(D)$
#
# <p style="margin: .0em"></p>
# - [ ] $P(D_{t})\leq P(D_{t+1})$,  $P(L_{t})\leq P(L_{t+1})$
# - [ ] $P(L_{0})=P(D_{t}\vert t<T)=0$
# - [ ] $P(D_{t})=D$ as $t\to\infty$
# - [ ] $P(L_{t})=L$ as $t\to\infty$
#
# <p style="margin: .0em"></p>
# - [ ] $P(I_{t})=1-P(L_{t})-P(D_{t})$
# - [ ] $P(I_{0})=1$
# - [ ] $P(I_{t})=0$ as $t\to\infty$
# :::
#
# ::::
#
# <hr>
#
# <div style="font-size: .5em">
# `D`: Learned parameter of the mature default rate as $t\rightarrow\infty$, e.g. `pm.Beta()`
# </div>

# %% [markdown]
# ## Modeling loan maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column width=50%}
# ```{.python code-line-numbers="5"}
# with pm.Model():
#     ...
#
#     D = ...
#     L = 1 - D
#
#     ...
# ```
# :::
#
# ::: {.column width=25% style="font-size: .7em;"}
# **First Principles TODO**
#
# - [x] $P(L) = 1 - P(D)$
#
# <p style="margin: .0em"></p>
# - [ ] $P(D_{t})\leq P(D_{t+1})$,  $P(L_{t})\leq P(L_{t+1})$
# - [ ] $P(L_{0})=P(D_{t}\vert t<T)=0$
# - [ ] $P(D_{t})=D$ as $t\to\infty$
# - [ ] $P(L_{t})=L$ as $t\to\infty$
#
# <p style="margin: .0em"></p>
# - [ ] $P(I_{t})=1-P(L_{t})-P(D_{t})$
# - [ ] $P(I_{0})=1$
# - [ ] $P(I_{t})=0$ as $t\to\infty$
# :::
#
# ::::
#
# <hr>
#
# <div style="font-size: .5em">
# `L`: The mature liquidation rate as $t\to\infty$
# </div>

# %% [markdown]
# ## Modeling loan maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column width=50%}
# ```{.python code-line-numbers="7-8"}
# with pm.Model():
#     ...
#
#     D = ...
#     L = 1 - D
#
#     D_t = D * some_cdf(t-T)
#     L_t = L * another_cdf(t)
#
#     ...
# ```
# :::
#
# ::: {.column width=25% style="font-size: .7em;"}
# **First Principles TODO**
#
# - [x] $P(L) = 1 - P(D)$
#
# <p style="margin: .0em"></p>
# - [x] $P(D_{t})\leq P(D_{t+1})$,  $P(L_{t})\leq P(L_{t+1})$
# - [x] $P(L_{0})=P(D_{t}\vert t<T)=0$
# - [x] $P(D_{t})=D$ as $t\to\infty$
# - [x] $P(L_{t})=L$ as $t\to\infty$
#
# <p style="margin: .0em"></p>
# - [ ] $P(I_{t})=1-P(L_{t})-P(D_{t})$
# - [ ] $P(I_{0})=1$
# - [ ] $P(I_{t})=0$ as $t\to\infty$
# :::
#
# ::::
#
# <hr>
#
# <div style="font-size: .5em">
# $D\times\text{some_cdf}: R^{+}\to[0,D]$
# <p></p>
# $L\times\text{another_cdf}: R^{+}\to[0,L]$
# </div>

# %% [markdown]
# ## Modeling loan maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column width=50%}
# ```{.python code-line-numbers="9"}
# with pm.Model():
#     ...
#
#     D = ...
#     L = 1 - D
#
#     D_t = D * some_cdf(t-T)
#     L_t = L * another_cdf(t)
#     I_t = 1 - D_t - L_t
#
#     ...
# ```
# :::
#
# ::: {.column width=25% style="font-size: .7em;"}
# **First Principles TODO**
#
# - [x] $P(L) = 1 - P(D)$
#
# <p style="margin: .0em"></p>
# - [x] $P(D_{t})\leq P(D_{t+1})$,  $P(L_{t})\leq P(L_{t+1})$
# - [x] $P(L_{0})=P(D_{t}\vert t<T)=0$
# - [x] $P(D_{t})=D$ as $t\to\infty$
# - [x] $P(L_{t})=L$ as $t\to\infty$
#
# <p style="margin: .0em"></p>
# - [x] $P(I_{t})=1-P(L_{t})-P(D_{t})$
# - [x] $P(I_{0})=1$
# - [x] $P(I_{t})=0$ as $t\to\infty$
# :::
#
# ::::
#
# <hr>
#
# <div style="font-size: .5em">
# `I_t`: The percentage of loans in-flight at time $t$
# </div>

# %% [markdown]
# ## Modeling Loan Maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column width=50%}
# ```{.python code-line-numbers="1,4-17"}
# with pm.Model():
#     ...
#
#     likelihood = pm.Multinomial(
#         'likelihood',
#         n=N,
#         p=[
#             D_t,
#             L_t,
#             I_t
#         ],
#         observed=[
#             default_at_t,
#             liquidation_at_t,
#             inflight_at_t,
#         ]
#     )
# ```
# :::
#
# ::: {.column width=25% style="font-size: .7em;"}
# **First Principles TODO**
#
# - [x] $P(L) = 1 - P(D)$
#
# <p style="margin: .0em"></p>
# - [x] $P(D_{t})\leq P(D_{t+1})$,  $P(L_{t})\leq P(L_{t+1})$
# - [x] $P(L_{0})=P(D_{t}\vert t<T)=0$
# - [x] $P(D_{t})=D$ as $t\to\infty$
# - [x] $P(L_{t})=L$ as $t\to\infty$
#
# <p style="margin: .0em"></p>
# - [x] $P(I_{t})=1-P(L_{t})-P(D_{t})$
# - [x] $P(I_{0})=1$
# - [x] $P(I_{t})=0$ as $t\to\infty$
# :::
#
# ::::
#
# <hr>
# <div style="font-size: .5em">
# Technically we need to do `pt.Stack(...).T` for `p` and `observed=`, but this makes the slide less readable.
# </div>

# %% [markdown]
# ## Modeling Loan Maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column}
# ```{.python code-line-numbers="4-17"}
#
# ...
#
# likelihood = pm.Multinomial(
#     'likelihood',
#     n=N,
#     p=[
#         D_t,
#         L_t,
#         I_t
#     ],
#     observed=[
#         default_at_t,
#         liquidation_at_t,
#         inflight_at_t,
#     ]
# )
# ```
# :::
#
# ::: {.column}
# **Advantages over vanilla ML**
#
# <div style="font-size: .7em">
# - Robust to overfitting
# - Model maps cleanly to the business model, not _just_ business outcomes
# - Easy to explain, easy to troubleshoot
# - Estimating 5 outcomes in one shot, all estimates are self-consistent
# - Suitable for modeling data when outcome is not directly observed
# </div>
# :::
#
# ::::

# %% [markdown]
# ## Modeling Loan Maturation {auto-animate=true visibility="uncounted"}

# %% [markdown]
# :::: {.columns}
#
# ::: {.column}
# ```{.python code-line-numbers="4-17"}
#
# ...
#
# likelihood = pm.Multinomial(
#     'likelihood',
#     n=N,
#     p=[
#         D_t,
#         L_t,
#         I_t
#     ],
#     observed=[
#         default_at_t,
#         liquidation_at_t,
#         inflight_at_t,
#     ]
# )
# ```
# :::
#
# ::: {.column}
# **Critiques**
#
# ::: {.fragments style="font-size: .7em"}
# - Models loan states, not balances
# - Models loans, not accounts: i.e. assumes independence
# - Assumes all loans are of similar risk
# - Does not account for growth
#     - e.g. `N` changing over time
#     - product improvements
#
# ::: {.fragment .highlight-blue}
# - No **_features!?_**
# :::
#
# :::
# :::
#
# ::::

# %% [markdown]
# # Awesome 2.0

# %% [markdown]
# ## Modeling with recovery {auto-animate=true}
#
# <br>
#
# ```{.python code-line-numbers="8-10,12"}
# with pm.Model as model:
#     ...
#
#     # R: learned parameter of recovery, e.g. pm.Beta()
#     # D_T: number of loans that defaulted `t-T` days ago
#     # PD_T: number of loans in a past-due state `t-T` days ago
#     # N: total number of loans
#     R = ...
#     D_t = (D_T + (1-R) * PD_T) / N
#     D = D_t / some_cdf(t-T)
#
#     # ↓↓↓ everything else same as before ↓↓↓
#
#     ...
# ```

# %% [markdown]
# ## Results
#
# <div align=center style="text-align: center">
# <image align=center width=50% src="https://static.vecteezy.com/system/resources/previews/005/337/799/original/icon-image-not-found-free-vector.jpg">
# </div>

# %% [markdown]
# # Discussion
#
# <h2>⚠️ Disclaimer</h2>
#
# <div style="font-size: 5em; text-align: center">
# >  👋
# </div>

# %% [markdown]
# ## Why industry?
#
# <br>
#
# From [Wikipedia](https://en.wikipedia.org/wiki/Data_generating_process),
#
# ![](assets/wiki-definition.png)

# %% [markdown]
# ## Why Bayesian? {auto-animate=true}
#
# Priors! All Bayesian models are DGPs!
#
# ![](assets/neon.png)

# %% [markdown]
# ## Why Bayesian? {auto-animate=true visibility=uncounted}
#
# Priors! All Bayesian models are DGPs!
#
# ![](assets/neon.png)
# ![](assets/silhouette.png){.absolute bottom=-150 left=275 width="600" height="900"}
# ![](assets/silhouette.png){.absolute bottom=-50 left=525 width="600" height="900"}

# %% [markdown]
# ## Why PyMCon?
#
# <br>
#
# <video data-autoplay src="assets/coding-putting-model.mov"></video>
#
# <br>
# <br>
# <br>
# <div style="vertical-align: bottom; font-size: .5em">
# <hr>
# Note: this code was simplified for the purpose of illustration and not quite correct. A better version can be found [here](https://colab.research.google.com/drive/1luKMwARuZPuu-CVqV_OU5kJTvC5e5Ogs).
# </div>

# %% [markdown]
# # Why should I care?

# %% [markdown]
# ## Humanz win
#
# <br>
#
# <div style="font-size: 3em">
# |🧍 | 1|
# |:--:|:--:|
# |🤖 | 0|
# </div>

# %% [markdown]
# # Perpay is Hiring {background-image=assets/perpay.png}
#
# ![](assets/qr-code.png){width=80% fig-align=center}

# %% [markdown]
# # Appendix {visibility=uncounted}

# %% [markdown]
# ## Tips {visibility=uncounted}
#
# - Start simple, add assumptions incrementally
# - Prior predictive sampling: do it
# - Think graphically: See [Narratively Generative Models](https://betanalpha.github.io/assets/case_studies/generative_modeling.html)
# - Get comfortable with basics of probability
#     - Know things like [law of total probability](https://en.wikipedia.org/wiki/Law_of_total_probability), rules of [conditional probability](https://en.wikipedia.org/wiki/Conditional_probability) and [joint probability](https://en.wikipedia.org/wiki/Joint_probability_distribution)
#     - Understand [expectations](https://en.wikipedia.org/wiki/Expected_value). Common gotcha: $\text{E}(f(\theta)) \ne f(\text{E}(\theta))$
#     - Work out expressions for [conjugate priors](https://en.wikipedia.org/wiki/Conjugate_prior) to build chops

# %% [markdown]
# ## Resources {visibility=uncounted}
#
# - Putting case study and extensions:
#     - [Original](https://mc-stan.org/users/documentation/case-studies/golf.html)
#     - [Colab notebook, companion to this talk](https://colab.research.google.com/drive/1luKMwARuZPuu-CVqV_OU5kJTvC5e5Ogs)
#     - [PyMC Example Gallery](https://www.pymc.io/projects/examples/en/latest/gallery.html)
# - Industry applications that are slightly more generic:
#     - [PyMC Labs x Hello Fresh](https://www.pymc-labs.io/blog-posts/reducing-customer-acquisition-costs-how-we-helped-optimizing-hellofreshs-marketing-budget/) Mixed Media Marketing
#     - [Pareto/NBD](http://brucehardie.com/notes/009/pareto_nbd_derivations_2005-11-05.pdf)
